# %%
# !pip install fastbook
# !pip install fastai
# Out:
# Collecting fastbook
#   Downloading fastbook-0.0.29-py3-none-any.whl (719 kB)
#      |████████████████████████████████| 719 kB 6.6 MB/s eta 0:00:01    |██▊                             | 61 kB 5.0 MB/s eta 0:00:01
# Collecting transformers
#   Downloading transformers-4.36.1-py3-none-any.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 30.9 MB/s eta 0:00:01
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 11.1 MB/s eta 0:00:01
# Requirement already satisfied: ipywidgets<8 in /opt/anaconda3/lib/python3.8/site-packages (from fastbook) (7.6.3)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.8/site-packages (from fastbook) (1.2.4)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.8/site-packages (from fastbook) (20.9)
# Collecting fastai>=2.6
#   Downloading fastai-2.7.13-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 12.5 MB/s eta 0:00:01
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp38-cp38-macosx_10_9_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 10.9 MB/s eta 0:00:01
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      |████████████████████████████████| 521 kB 13.7 MB/s eta 0:00:01
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.8/site-packages (from fastbook) (21.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from fastbook) (2.25.1)
# Collecting spacy<4
#   Downloading spacy-3.7.2-cp38-cp38-macosx_10_9_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 23.2 MB/s eta 0:00:01
# Collecting torchvision>=0.11
#   Downloading torchvision-0.16.2-cp38-cp38-macosx_10_13_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 27.2 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.8/site-packages (from fastai>=2.6->fastbook) (1.6.2)
# Collecting fastprogress>=0.2.4
#   Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.8/site-packages (from fastai>=2.6->fastbook) (3.3.4)
# Collecting fastcore<1.6,>=1.5.29
#   Downloading fastcore-1.5.29-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 20.6 MB/s eta 0:00:01
# Collecting pillow>=9.0.0
#   Downloading Pillow-10.1.0-cp38-cp38-macosx_10_10_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 19.1 MB/s eta 0:00:01
# Collecting torch<2.2,>=1.10
#   Downloading torch-2.1.2-cp38-none-macosx_10_9_x86_64.whl (146.7 MB)
#      |████████████████████████████████| 146.7 MB 31.5 MB/s eta 0:00:01    |████                            | 18.2 MB 45.9 MB/s eta 0:00:03
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.8/site-packages (from fastai>=2.6->fastbook) (5.4.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.8/site-packages (from fastai>=2.6->fastbook) (0.24.1)
# Requirement already satisfied: ipython>=4.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8->fastbook) (7.22.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8->fastbook) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8->fastbook) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8->fastbook) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8->fastbook) (5.0.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8->fastbook) (3.5.1)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (0.1.2)
# Requirement already satisfied: jupyter-client in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8->fastbook) (6.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (52.0.0.post20210125)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (4.8.0)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.15.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.17)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.5)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (5.0.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.0)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8->fastbook) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8->fastbook) (3.2.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8->fastbook) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8->fastbook) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8->fastbook) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai>=2.6->fastbook) (4.59.0)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 26.3 MB/s eta 0:00:01
# Collecting weasel<0.4.0,>=0.1.0
#   Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 48.5 MB/s  eta 0:00:01
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.20.1)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 98.7 MB/s eta 0:00:01
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp38-cp38-macosx_10_9_x86_64.whl (490 kB)
#      |████████████████████████████████| 490 kB 41.3 MB/s eta 0:00:01
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting thinc<8.3.0,>=8.1.8
#   Downloading thinc-8.2.2-cp38-cp38-macosx_10_9_x86_64.whl (860 kB)
#      |████████████████████████████████| 860 kB 41.3 MB/s eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp38-cp38-macosx_10_9_x86_64.whl (42 kB)
#      |████████████████████████████████| 42 kB 10.7 MB/s  eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp38-cp38-macosx_10_9_x86_64.whl (26 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.10.11)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 28.1 MB/s  eta 0:00:01
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp38-cp38-macosx_10_9_x86_64.whl (135 kB)
#      |████████████████████████████████| 135 kB 27.3 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging->fastbook) (2.4.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (4.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->fastbook) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->fastbook) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->fastbook) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->fastbook) (2.10)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp38-cp38-macosx_10_9_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 87.4 MB/s eta 0:00:01
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.8/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (0.9.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.8/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (2.5)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.8/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (3.0.12)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.8/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (1.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (7.1.2)
# Collecting cloudpathlib<0.17.0,>=0.7.0
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 22.5 MB/s eta 0:00:01
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (6.3.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.9.4)
# Requirement already satisfied: argon2-cffi in /opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (20.0.0)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.10.1)
# Requirement already satisfied: nbconvert in /opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (6.0.7)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8->fastbook) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.14.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (2.20)
# Collecting pyarrow-hotfix
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 55.4 MB/s eta 0:00:01
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.8/site-packages (from datasets->fastbook) (3.8.4)
# Collecting fsspec[http]<=2023.10.0,>=2023.1.0
#   Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 43.1 MB/s eta 0:00:01
# Collecting tqdm<5.0.0,>=4.38.0
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 43.3 MB/s  eta 0:00:01
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from datasets->fastbook) (12.0.0)
# Collecting xxhash
#   Downloading xxhash-3.4.1-cp38-cp38-macosx_10_9_x86_64.whl (31 kB)
# Collecting huggingface-hub>=0.18.0
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#      |████████████████████████████████| 311 kB 66.6 MB/s eta 0:00:01
# Collecting multiprocess
#   Downloading multiprocess-0.70.15-py38-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 33.4 MB/s eta 0:00:01
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets->fastbook) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets->fastbook) (3.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets->fastbook) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets->fastbook) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets->fastbook) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets->fastbook) (6.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai>=2.6->fastbook) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai>=2.6->fastbook) (1.3.1)
# Requirement already satisfied: testpath in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.4.4)
# Requirement already satisfied: bleach in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (3.3.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.8.4)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.3)
# Requirement already satisfied: async-generator in /opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.10)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8->fastbook) (0.5.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas->fastbook) (2021.1)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai>=2.6->fastbook) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai>=2.6->fastbook) (2.1.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.8/site-packages (from sympy->torch<2.2,>=1.10->fastai>=2.6->fastbook) (1.2.1)
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.4.1-cp38-cp38-macosx_10_7_x86_64.whl (443 kB)
#      |████████████████████████████████| 443 kB 100.8 MB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.8/site-packages (from transformers->fastbook) (2021.4.4)
# Collecting tokenizers<0.19,>=0.14
#   Downloading tokenizers-0.15.0-cp38-cp38-macosx_10_7_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 70.1 MB/s eta 0:00:01
# Installing collected packages: catalogue, srsly, murmurhash, cymem, wasabi, typer, tqdm, smart-open, preshed, fsspec, confection, cloudpathlib, blis, weasel, torch, thinc, spacy-loggers, spacy-legacy, pillow, langcodes, huggingface-hub, fastprogress, fastcore, dill, xxhash, torchvision, tokenizers, spacy, safetensors, pyarrow-hotfix, multiprocess, fastdownload, transformers, sentencepiece, graphviz, fastai, datasets, fastbook
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.59.0
#     Uninstalling tqdm-4.59.0:
#       Successfully uninstalled tqdm-4.59.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 0.9.0
#     Uninstalling fsspec-0.9.0:
#       Successfully uninstalled fsspec-0.9.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.2.0
#     Uninstalling Pillow-8.2.0:
#       Successfully uninstalled Pillow-8.2.0
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 datasets-2.15.0 dill-0.3.7 fastai-2.7.13 fastbook-0.0.29 fastcore-1.5.29 fastdownload-0.0.7 fastprogress-1.0.3 fsspec-2023.10.0 graphviz-0.20.1 huggingface-hub-0.19.4 langcodes-3.3.0 multiprocess-0.70.15 murmurhash-1.0.10 pillow-10.1.0 preshed-3.0.9 pyarrow-hotfix-0.6 safetensors-0.4.1 sentencepiece-0.1.99 smart-open-6.4.0 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.2 tokenizers-0.15.0 torch-2.1.2 torchvision-0.16.2 tqdm-4.66.1 transformers-4.36.1 typer-0.9.0 wasabi-1.1.2 weasel-0.3.4 xxhash-3.4.1
# Requirement already satisfied: fastai in /opt/anaconda3/lib/python3.8/site-packages (2.7.13)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (2.25.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (20.9)
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (21.0.1)
# Requirement already satisfied: spacy<4 in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (3.7.2)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.5.29)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.2.4)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (5.4.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (3.3.4)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (10.1.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (0.24.1)
# Requirement already satisfied: torch<2.2,>=1.10 in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (2.1.2)
# Requirement already satisfied: torchvision>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (0.16.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.6.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (3.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (52.0.0.post20210125)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (8.2.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.0.10)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.20.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.10.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (0.9.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (0.3.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (6.4.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (4.66.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging->fastai) (2.4.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (4.6.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai) (0.7.11)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.8/site-packages (from torch<2.2,>=1.10->fastai) (2023.10.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.8/site-packages (from torch<2.2,>=1.10->fastai) (2.5)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.8/site-packages (from torch<2.2,>=1.10->fastai) (3.0.12)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.8/site-packages (from torch<2.2,>=1.10->fastai) (1.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai) (7.1.2)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<4->fastai) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (1.3.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->fastai) (1.15.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from networkx->torch<2.2,>=1.10->fastai) (5.0.6)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas->fastai) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (1.0.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.8/site-packages (from sympy->torch<2.2,>=1.10->fastai) (1.2.1)

# %%
from fastbook import *
from fastai.vision.widgets import *

# %%
learn_inf = load_learner('export.pkl')

# %%
btn_upload = widgets.FileUpload()
btn_run = widgets.Button(description='Classify')

# %%
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
    
btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Select your bear!'),
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.5.5-py3-none-any.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 7.7 MB/s eta 0:00:01
# Requirement already satisfied: traitlets<6,>=5.0.3 in /opt/anaconda3/lib/python3.8/site-packages (from voila) (5.0.5)
# Collecting nbconvert<8,>=6.4.5
#   Downloading nbconvert-7.12.0-py3-none-any.whl (256 kB)
#      |████████████████████████████████| 256 kB 110.6 MB/s eta 0:00:01
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from voila) (2.4.0)
# Collecting jupyter-client<9,>=7.4.4
#   Downloading jupyter_client-8.6.0-py3-none-any.whl (105 kB)
#      |████████████████████████████████| 105 kB 53.2 MB/s eta 0:00:01
# Collecting jupyter-server<3,>=2.0.0
#   Downloading jupyter_server-2.12.1-py3-none-any.whl (380 kB)
#      |████████████████████████████████| 380 kB 91.4 MB/s eta 0:00:01
# Collecting websockets>=9.0
#   Downloading websockets-12.0-cp38-cp38-macosx_10_9_x86_64.whl (121 kB)
#      |████████████████████████████████| 121 kB 63.9 MB/s eta 0:00:01
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from voila) (0.5.3)
# Collecting jupyter-core>=4.11.0
#   Downloading jupyter_core-5.5.0-py3-none-any.whl (28 kB)
# Collecting traitlets<6,>=5.0.3
#   Downloading traitlets-5.14.0-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 21.3 MB/s eta 0:00:01
# Collecting tornado>=6.2
#   Downloading tornado-6.4-cp38-abi3-macosx_10_9_x86_64.whl (431 kB)
#      |████████████████████████████████| 431 kB 92.2 MB/s eta 0:00:01
# Collecting python-dateutil>=2.8.2
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pyzmq>=23.0
#   Downloading pyzmq-25.1.2-cp38-cp38-macosx_10_15_universal2.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 107.0 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata>=4.8.3 in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<9,>=7.4.4->voila) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyter-client<9,>=7.4.4->voila) (3.4.1)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-4.1.0-py3-none-any.whl (17 kB)
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.5.0-py3-none-any.whl (13 kB)
# Collecting anyio>=3.1.0
#   Downloading anyio-4.1.0-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 12.3 MB/s eta 0:00:011
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.9.4)
# Collecting websocket-client
#   Downloading websocket_client-1.7.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 27.2 MB/s eta 0:00:011
# Requirement already satisfied: argon2-cffi in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-server<3,>=2.0.0->voila) (20.1.0)
# Collecting jupyter-events>=0.9.0
#   Downloading jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Collecting nbformat>=5.3.0
#   Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 41.6 MB/s eta 0:00:011
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-server<3,>=2.0.0->voila) (2.11.3)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.10.1)
# Collecting overrides
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-server<3,>=2.0.0->voila) (20.9)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (2.10)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (5.4.1)
# Collecting jsonschema[format-nongpl]>=4.18.0
#   Downloading jsonschema-4.20.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 20.3 MB/s eta 0:00:01
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting referencing
#   Downloading referencing-0.32.0-py3-none-any.whl (26 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2023.11.2-py3-none-any.whl (17 kB)
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.13.2-cp38-cp38-macosx_10_7_x86_64.whl (337 kB)
#      |████████████████████████████████| 337 kB 110.0 MB/s eta 0:00:01
# Collecting attrs>=22.2.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 35.5 MB/s eta 0:00:01
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting webcolors>=1.11
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Requirement already satisfied: json5 in /opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.5)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.25.1)
# Requirement already satisfied: babel in /opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.9.0)
# Collecting jupyterlab-server<3,>=2.3.0
#   Downloading jupyterlab_server-2.25.2-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 46.8 MB/s  eta 0:00:01
# Collecting requests>=2.31
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 9.5 MB/s  eta 0:00:011
# Collecting babel>=2.10
#   Downloading Babel-2.14.0-py3-none-any.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 72.2 MB/s eta 0:00:01
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 26.0 MB/s eta 0:00:01
# Collecting packaging
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 11.2 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2015.7 in /opt/anaconda3/lib/python3.8/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2021.1)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp38-cp38-macosx_10_9_x86_64.whl (13 kB)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.8,>=0.4.0->voila) (1.5.1)
# Requirement already satisfied: async-generator in /opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.8,>=0.4.0->voila) (1.10)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (0.1.2)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 25.9 MB/s  eta 0:00:01
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (1.4.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (3.3.0)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (4.9.3)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (2.15.1)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.15.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.19.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2020.12.5)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.0.0->voila) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->jupyter-server<3,>=2.0.0->voila) (1.14.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<3,>=2.0.0->voila) (2.20)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.2.1)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 7.8 MB/s eta 0:00:011
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Installing collected packages: rpds-py, attrs, referencing, importlib-resources, types-python-dateutil, traitlets, python-dateutil, platformdirs, pkgutil-resolve-name, jsonschema-specifications, tornado, pyzmq, jupyter-core, jsonschema, fastjsonschema, arrow, webcolors, uri-template, rfc3986-validator, rfc3339-validator, packaging, nbformat, MarkupSafe, jupyter-client, jsonpointer, isoduration, fqdn, tinycss2, python-json-logger, mistune, jinja2, exceptiongroup, websocket-client, send2trash, overrides, nbconvert, jupyter-server-terminals, jupyter-events, anyio, requests, jupyter-server, babel, websockets, jupyterlab-server, voila
#   Attempting uninstall: attrs
#     Found existing installation: attrs 20.3.0
#     Uninstalling attrs-20.3.0:
#       Successfully uninstalled attrs-20.3.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.5
#     Uninstalling traitlets-5.0.5:
#       Successfully uninstalled traitlets-5.0.5
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 20.0.0
#     Uninstalling pyzmq-20.0.0:
#       Successfully uninstalled pyzmq-20.0.0
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.7.1
#     Uninstalling jupyter-core-4.7.1:
#       Successfully uninstalled jupyter-core-4.7.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 3.2.0
#     Uninstalling jsonschema-3.2.0:
#       Successfully uninstalled jsonschema-3.2.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.1.3
#     Uninstalling nbformat-5.1.3:
#       Successfully uninstalled nbformat-5.1.3
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: send2trash
#     Found existing installation: Send2Trash 1.5.0
#     Uninstalling Send2Trash-1.5.0:
#       Successfully uninstalled Send2Trash-1.5.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
#   Attempting uninstall: anyio
#     Found existing installation: anyio 2.2.0
#     Uninstalling anyio-2.2.0:
#       Successfully uninstalled anyio-2.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.4.1
#     Uninstalling jupyter-server-1.4.1:
#       Successfully uninstalled jupyter-server-1.4.1
#   Attempting uninstall: babel
#     Found existing installation: Babel 2.9.0
#     Uninstalling Babel-2.9.0:
#       Successfully uninstalled Babel-2.9.0
#   Attempting uninstall: jupyterlab-server
#     Found existing installation: jupyterlab-server 2.4.0
#     Uninstalling jupyterlab-server-2.4.0:
#       Successfully uninstalled jupyterlab-server-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.5 requires pyqt5<5.13, which is not installed.
# spyder 4.2.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# sphinx 4.0.1 requires Jinja2<3.0,>=2.3, but you have jinja2 3.1.2 which is incompatible.
# sphinx 4.0.1 requires MarkupSafe<2.0, but you have markupsafe 2.1.3 which is incompatible.
# nbclassic 0.2.6 requires jupyter-server~=1.1, but you have jupyter-server 2.12.1 which is incompatible.
# jupyterlab 3.0.14 requires jupyter-server~=1.4, but you have jupyter-server 2.12.1 which is incompatible.
# Successfully installed MarkupSafe-2.1.3 anyio-4.1.0 arrow-1.3.0 attrs-23.1.0 babel-2.14.0 exceptiongroup-1.2.0 fastjsonschema-2.19.0 fqdn-1.5.1 importlib-resources-6.1.1 isoduration-20.11.0 jinja2-3.1.2 jsonpointer-2.4 jsonschema-4.20.0 jsonschema-specifications-2023.11.2 jupyter-client-8.6.0 jupyter-core-5.5.0 jupyter-events-0.9.0 jupyter-server-2.12.1 jupyter-server-terminals-0.5.0 jupyterlab-server-2.25.2 mistune-3.0.2 nbconvert-7.12.0 nbformat-5.9.2 overrides-7.4.0 packaging-23.2 pkgutil-resolve-name-1.3.10 platformdirs-4.1.0 python-dateutil-2.8.2 python-json-logger-2.0.7 pyzmq-25.1.2 referencing-0.32.0 requests-2.31.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.13.2 send2trash-1.8.2 tinycss2-1.2.1 tornado-6.4 traitlets-5.14.0 types-python-dateutil-2.8.19.14 uri-template-1.3.0 voila-0.5.5 webcolors-1.13 websocket-client-1.7.0 websockets-12.0
# Enabling: voila
# - Writing config: /opt/anaconda3/etc/jupyter
#     - Validating...
#       voila 0.5.5 OK
